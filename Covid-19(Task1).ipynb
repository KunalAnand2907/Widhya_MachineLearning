# %% [markdown]
# # Covid-19 Analysis
# <B> TASK 1</B>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\KUNAL\Documents\Widhya_Internship\covid19.txt', sep = ',', header =0 , engine = 'python', encoding = 'latin-1')
data=data.drop(data.columns[0],axis=1)
data
# Out:
#          Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    30/01/20               Kerala                        1
# 1    31/01/20               Kerala                        1
# 2    01/02/20               Kerala                        2
# 3    02/02/20               Kerala                        3
# 4    03/02/20               Kerala                        3
# ..        ...                  ...                      ...
# 265  21/03/20    Jammu and Kashmir                        4
# 266  21/03/20               Ladakh                       13
# 267  21/03/20        Uttar Pradesh                       23
# 268  21/03/20          Uttarakhand                        3
# 269  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# 3                           0      0       0
# ...

# %%
grouped_data=data.groupby("Date",sort=False,axis=0)
grouped_data=grouped_data.agg({'ConfirmedIndianNational':['sum'],'ConfirmedForeignNational':['sum'],'Cured':['sum'],'Deaths':['sum']})
grouped_data
# Out:
#          ConfirmedIndianNational ConfirmedForeignNational Cured Deaths
#                              sum                      sum   sum    sum
# Date
# 30/01/20                       1                        0     0      0
# 31/01/20                       1                        0     0      0
# 01/02/20                       2                        0     0      0
# 02/02/20                       3                        0     0      0
# 03/02/20                       3                        0     0      0
# 04/02/20                       3                        0     0      0
# 05/02/20                       3                        0     0      0
# 06/02/20                       3                        0     0      0
# 07/02/20                       3                        0     0      0
# 08/02/20                       3                        0     0      0
# 09/02/20                       3                        0     0      0
# ...

# %%
data.sum()
data[data.Date=="04/03/20"]
# Out:
#         Date State/UnionTerritory  ConfirmedIndianNational  \
# 39  04/03/20        Uttar Pradesh                        6
# 40  04/03/20               Kerala                        3
# 41  04/03/20              Haryana                        0
# 42  04/03/20                Delhi                        1
# 43  04/03/20            Telengana                        1
# 44  04/03/20            Rajasthan                        1
#
#     ConfirmedForeignNational  Cured  Deaths
# 39                         0      0       0
# 40                         0      3       0
# 41                         2      0       0
# 42                         0      0       0
# 43                         0      0       0
# 44                        14      0       0

# %%
grouped=data.groupby("Date",sort=False,axis=0)
grouped=grouped.agg({'ConfirmedIndianNational':['sum'],'ConfirmedForeignNational':['sum']})
grouped
# Out:
#          ConfirmedIndianNational ConfirmedForeignNational
#                              sum                      sum
# Date
# 30/01/20                       1                        0
# 31/01/20                       1                        0
# 01/02/20                       2                        0
# 02/02/20                       3                        0
# 03/02/20                       3                        0
# 04/02/20                       3                        0
# 05/02/20                       3                        0
# 06/02/20                       3                        0
# 07/02/20                       3                        0
# 08/02/20                       3                        0
# 09/02/20                       3                        0
# 10/02/20                       3                        0
# 11/02/20                       3                        0
# 12/02/20                       3                        0
# ...

# %%
Sumed=grouped['ConfirmedIndianNational']+grouped['ConfirmedForeignNational']
grouped['CombinedCases']=Sumed
Data = grouped['CombinedCases']
Data
# Out:
# Date
# 30/01/20      1
# 31/01/20      1
# 01/02/20      2
# 02/02/20      3
# 03/02/20      3
# 04/02/20      3
# 05/02/20      3
# 06/02/20      3
# 07/02/20      3
# 08/02/20      3
# 09/02/20      3
# 10/02/20      3
# 11/02/20      3
# 12/02/20      3
# 13/02/20      3
# 14/02/20      3
# 15/02/20      3
# 16/02/20      3
# 17/02/20      3
# 18/02/20      3
# 19/02/20      3
# 20/02/20      3
# 21/02/20      3
# 22/02/20      3
# 23/02/20      3
# 24/02/20      3
# 25/02/20      3
# 26/02/20      3
# 27/02/20      3
# 28/02/20      3
# 29/02/20      3
# 01/03/20      3
# 02/03/20      5
# 03/03/20      6
# 04/03/20     28
# 05/03/20     30
# 06/03/20     31
# 07/03/20     34
# 08/03/20     39
# 09/03/20     46
# 10/03/20     58
# 11/03/20     60
# 12/03/20     74
# 13/03/20     81
# 14/03/20     84
# 15/03/20    110
# 16/03/20    114
# 17/03/20    137
# 18/03/20    151
# 19/03/20    173
# 20/03/20    223
# 21/03/20    283
# Name: CombinedCases, dtype: int64

# %% [markdown]
# ### Combining Indian & Foreign Cases

# %%
Data = pd.DataFrame(grouped['CombinedCases'])
Data
# Out:
#           CombinedCases
# Date
# 30/01/20              1
# 31/01/20              1
# 01/02/20              2
# 02/02/20              3
# 03/02/20              3
# 04/02/20              3
# 05/02/20              3
# 06/02/20              3
# 07/02/20              3
# 08/02/20              3
# 09/02/20              3
# 10/02/20              3
# 11/02/20              3
# 12/02/20              3
# 13/02/20              3
# 14/02/20              3
# 15/02/20              3
# 16/02/20              3
# 17/02/20              3
# 18/02/20              3
# 19/02/20              3
# 20/02/20              3
# 21/02/20              3
# 22/02/20              3
# 23/02/20              3
# 24/02/20              3
# 25/02/20              3
# 26/02/20              3
# 27/02/20              3
# 28/02/20              3
# 29/02/20              3
# 01/03/20              3
# 02/03/20              5
# 03/03/20              6
# 04/03/20             28
# 05/03/20             30
# 06/03/20             31
# ...

# %%
Data.iloc[34]
# Out:
# Date
# 30/01/20      1
# 31/01/20      1
# 01/02/20      2
# 02/02/20      3
# 03/02/20      3
# 04/02/20      3
# 05/02/20      3
# 06/02/20      3
# 07/02/20      3
# 08/02/20      3
# 09/02/20      3
# 10/02/20      3
# 11/02/20      3
# 12/02/20      3
# 13/02/20      3
# 14/02/20      3
# 15/02/20      3
# 16/02/20      3
# 17/02/20      3
# 18/02/20      3
# 19/02/20      3
# 20/02/20      3
# 21/02/20      3
# 22/02/20      3
# 23/02/20      3
# 24/02/20      3
# 25/02/20      3
# 26/02/20      3
# 27/02/20      3
# 28/02/20      3
# 29/02/20      3
# 01/03/20      3
# 02/03/20      5
# 03/03/20      6
# 04/03/20     28
# 05/03/20     30
# 06/03/20     31
# 07/03/20     34
# 08/03/20     39
# 09/03/20     46
# 10/03/20     58
# 11/03/20     60
# 12/03/20     74
# 13/03/20     81
# 14/03/20     84
# 15/03/20    110
# 16/03/20    114
# 17/03/20    137
# 18/03/20    151
# 19/03/20    173
# 20/03/20    223
# 21/03/20    283
# Name: CombinedCases, dtype: int64

# %% [markdown]
# ### Finding the Rate of Increase Value

# %%
for i in Data.iterrows(range(34,52)):
    for j in Data.iterrows(range(i+1,52)):
        r=(j.iloc[35] - i.iloc[34])/i.iloc[34]
        break
print(r)

# %%
 (df
   ...: .groupby(['col1', 'col2'])
   ...: .agg({
   ...:     'col3': ['mean', 'count'], 
   ...:     'col4': ['median', 'min', 'count']
   ...: }))
